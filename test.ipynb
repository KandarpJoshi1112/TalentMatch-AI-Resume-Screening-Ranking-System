# %%
from src.parse_resumes import extract_text_from_pdf

path = "sample_data/resumes/sample_resume.pdf"
text = extract_text_from_pdf(path)
print(text[:1000])  # print first 1000 chars
print("\nLength of text:", len(text))
# Out:
# joshikandarp.work@gmail.com
# Kandarp Joshi
# KandarpJoshi1112
# Education  Kandarp Josh i
# V.V.P Engineering College  Sep 2023  - July  2026
# B.E. (Computer  Science)  CGPA:  8.96
# A.V. Parekh Technical Institute  Sep 2020  -June  2023
# Diploma  (Computer Engineering)  CGPA: 9.65
# Experience
# Google Developer Groups (GDG) On Campus  VVP  Sep 2024  - Present
# Technical Lead   Rajkot , Gujarat
# - Spearheading a core technical team of 4 members to plan, develop, and execute 3+ technical events and workshops, each attracting
# over 100 participants.
# - Collaborated with cross -functional teams including management, design, and public relations to build a vibrant and inclusive tech
# community on campus.
# - Designed and conducted hands -on coding sessions enhancing peer learning and practical skill development.
# - Provided mentorship to team members, fostering growth in technical skills and leadership abilities.
# Projects
# ...
